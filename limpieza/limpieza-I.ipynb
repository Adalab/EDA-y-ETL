# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Pair Programming Limpieza I
#
# 1. Explora el dataset con los métodos que hemos ido aprendiendo hasta ahora para familiarizarnos con los datos.

# %%
def exploracion(dataframe, nombre):
    '''
    Función que nos permite explorar varios aspectos de un dataframe mostrando
    unas filas, el numero de filas y columnas, los tipos de datos, la cantidad de nulos por columna,
    la cantidad de filas duplicadas, y los principales estadísticos.
        Parametros:
                dataframe (dataframe): un dataframe que queremos explorar
                nombre (string): un titulo para el dataframe
    '''
    print(f"Exploracion del dataframe '{nombre}'")
    print(".............................................")
    print(f"En el dataframe hay {dataframe.shape[0]} filas y {dataframe.shape[1]} columnas.")
    print(".............................................")    
    print(f"5 filas aleatorias:")
    display(dataframe.sample(5))
    print(".............................................")
    print(f"Los tipos de data por columna del dataframe son:")
    display(dataframe.dtypes.reset_index())
    print(".............................................")
    print(f"La cantidad de nulos por columna del dataframe son:")
    display(dataframe.isnull().sum().reset_index())
    print(".............................................")
    print(f"El porcentaje de nulos por columna del dataframe son:")
    display(dataframe.isnull().sum() * 100 / dataframe.shape[0])
    print(".............................................")
    if dataframe.duplicated().sum() != 0:
        print(f"En el dataframe hay {dataframe.duplicated().sum()} filas duplicadas.")
    else:
        print(f"No hay filas duplicadas.")
    print(".............................................")
    print(f"Los principales estadísticos de las columnas numéricas son:")
    display(dataframe.describe())
    print(".............................................")
    print(f"Los principales estadísticos de las columnas categóricas son:")
    display(dataframe.describe(include=object))
    print(".............................................")

# %%
df = pd.read_csv('datos/bank-additional-full.csv', index_col=0)

# %%
exploracion(df, "Bank")
# Out:
# Exploracion del dataframe 'Bank'
# .............................................
# En el dataframe hay 43170 filas y 20 columnas.
# .............................................
# 5 filas aleatorias:
#        age            job   marital            education  default  housing  \
# 24602   35    blue-collar   MARRIED             basic.9y      0.0      1.0
# 23973   33         admin.    SINGLE    university.degree      0.0      0.0
# 30761   55  self-employed   MARRIED             basic.9y      0.0      1.0
# 1401    36     technician  DIVORCED  professional.course      0.0      1.0
# 19368   59      housemaid   MARRIED             basic.4y      NaN      0.0
#
#        loan    contact  duration  campaign  pdays  previous     poutcome  \
# 24602   0.0   cellular       101         2    999         1      FAILURE
# 23973   0.0   cellular        35         3    999         0  NONEXISTENT
# 30761   0.0   cellular       604         1    999         0  NONEXISTENT
# 1401    0.0  telephone       223         2    999         0  NONEXISTENT
# 19368   0.0   cellular       291         2    999         0  NONEXISTENT
#
#        emp.var.rate cons.price.idx cons.conf.idx euribor3m nr.employed   y  \
# 24602          -0.1           93,2         -42,0     4,191      5195,8  no
# 23973           1.4         93,444         -36,1     4,963      5228,1  no
# 30761          -1.8         92,893         -46,2     1,344      5099,1  no
# 1401            1.1         93,994         -36,4     4,855      5191,0  no
# 19368           1.4         93,444         -36,1     4,967      5228,1  no
#
#        month_day_week
# 24602  ['nov', 'mon']
# 23973  ['aug', 'fri']
# 30761  ['may', 'tue']
# 1401   ['may', 'thu']
# 19368  ['aug', 'wed']
# .............................................
# Los tipos de data por columna del dataframe son:
#              index        0
# 0              age    int64
# 1              job   object
# 2          marital   object
# 3        education   object
# 4          default  float64
# 5          housing  float64
# 6             loan  float64
# 7          contact   object
# 8         duration    int64
# 9         campaign    int64
# 10           pdays    int64
# 11        previous    int64
# 12        poutcome   object
# 13    emp.var.rate  float64
# 14  cons.price.idx   object
# 15   cons.conf.idx   object
# 16       euribor3m   object
# 17     nr.employed   object
# 18               y   object
# 19  month_day_week   object
# .............................................
# La cantidad de nulos por columna del dataframe son:
#              index     0
# 0              age     0
# 1              job   347
# 2          marital    85
# 3        education  1815
# 4          default  9016
# 5          housing  1031
# 6             loan  1031
# 7          contact     0
# 8         duration     0
# 9         campaign     0
# 10           pdays     0
# 11        previous     0
# 12        poutcome     0
# 13    emp.var.rate     0
# 14  cons.price.idx     0
# 15   cons.conf.idx     0
# 16       euribor3m     0
# 17     nr.employed     0
# 18               y     0
# 19  month_day_week     0
# .............................................
# El porcentaje de nulos por columna del dataframe son:
# age                0.000000
# job                0.803799
# marital            0.196896
# education          4.204309
# default           20.884874
# housing            2.388233
# loan               2.388233
# contact            0.000000
# duration           0.000000
# campaign           0.000000
# pdays              0.000000
# previous           0.000000
# poutcome           0.000000
# emp.var.rate       0.000000
# cons.price.idx     0.000000
# cons.conf.idx      0.000000
# euribor3m          0.000000
# nr.employed        0.000000
# y                  0.000000
# month_day_week     0.000000
# dtype: float64
# .............................................
# En el dataframe hay 1994 filas duplicadas.
# .............................................
# Los principales estadísticos de las columnas numéricas son:
#                 age       default       housing          loan      duration  \
# count  43170.000000  34154.000000  42139.000000  42139.000000  43170.000000
# mean      40.014918      0.000088      0.535869      0.155652    257.883739
# std       10.407327      0.009372      0.498718      0.362529    259.393738
# min       17.000000      0.000000      0.000000      0.000000      0.000000
# 25%       32.000000      0.000000      0.000000      0.000000    102.000000
# 50%       38.000000      0.000000      1.000000      0.000000    179.000000
# 75%       47.000000      0.000000      1.000000      0.000000    319.000000
# max       98.000000      1.000000      1.000000      1.000000   4918.000000
#
#            campaign         pdays      previous  emp.var.rate
# count  43170.000000  43170.000000  43170.000000  43170.000000
# mean       2.564675    962.452282      0.173639      0.078177
# std        2.768538    186.962379      0.496750      1.572217
# min        1.000000      0.000000      0.000000     -3.400000
# 25%        1.000000    999.000000      0.000000     -1.800000
# 50%        2.000000    999.000000      0.000000      1.100000
# 75%        3.000000    999.000000      0.000000      1.400000
# max       56.000000    999.000000      7.000000      1.400000
# .............................................
# Los principales estadísticos de las columnas categóricas son:
#            job  marital          education   contact     poutcome  \
# count    42823    43085              41355     43170        43170
# unique      11        3                  7         2            3
# top     admin.  MARRIED  university.degree  cellular  NONEXISTENT
# freq     10918    26105              12766     27438        37261
#
#        cons.price.idx cons.conf.idx euribor3m nr.employed      y  \
# count           43170         43170     43170       43170  43170
# unique             26            26       316          11      2
# top            93,994         -36,4     4,857      5228,1     no
# freq             8117          8117      3002       16981  38308
#
#         month_day_week
# count            43170
# unique              50
# top     ['may', 'wed']
# freq              3039
# .............................................

# %% [markdown]
# 2. Cambia el nombre de las columnas para que no tengan puntos en el nombre. En concreto, reemplazad los "." por comas.

# %%
# reemplazamos los '.' por '_' en vez de comas

diccionario = {col : col.replace('.', '_').lower() for col in df.columns}

df.rename(columns = diccionario, inplace=True)

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'duration', 'campaign', 'pdays', 'previous', 'poutcome',
#        'emp_var_rate', 'cons_price_idx', 'cons_conf_idx', 'euribor3m',
#        'nr_employed', 'y', 'month_day_week'],
#       dtype='object')

# %% [markdown]
# 3. ¿Hay valores duplicados en nuestro dataframe? En caso de que los haya, eliminándlos.

# %%
df.duplicated().sum()
# Out:
# 1994

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (41176, 20)

# %% [markdown]
# 4. Como hemos visto, algunas columnas no tienen el tipo de datos que deberían. Cambiad el tipo de dato para las columnas de cons.price.idx, cons.conf.idx, euribor3m, nr.employed.

# %%
df[['cons_price_idx', 'cons_conf_idx', 'euribor3m', 'nr_employed']] = df[['cons_price_idx', 'cons_conf_idx', 'euribor3m', 'nr_employed']].replace(r',', '.', regex=True)

# %%
df.head(3)
# Out:
#    age        job  marital    education  default  housing  loan    contact  \
# 0   56  housemaid  MARRIED     basic.4y      0.0      0.0   0.0  telephone
# 1   57   services  MARRIED  high.school      NaN      0.0   0.0  telephone
# 2   37   services  MARRIED  high.school      0.0      1.0   0.0  telephone
#
#    duration  campaign  pdays  previous     poutcome  emp_var_rate  \
# 0       261         1    999         0  NONEXISTENT           1.1
# 1       149         1    999         0  NONEXISTENT           1.1
# 2       226         1    999         0  NONEXISTENT           1.1
#
#   cons_price_idx cons_conf_idx euribor3m nr_employed   y  month_day_week
# 0         93.994         -36.4     4.857      5191.0  no  ['may', 'mon']
# 1         93.994         -36.4     4.857      5191.0  no  ['may', 'mon']
# 2         93.994         -36.4     4.857      5191.0  no  ['may', 'mon']

# %%
df[['cons_price_idx', 'cons_conf_idx', 'euribor3m', 'nr_employed']] = df[['cons_price_idx', 'cons_conf_idx', 'euribor3m', 'nr_employed']].astype('float64', errors = 'ignore')

# %%
df.dtypes
# Out:
# age                 int64
# job                object
# marital            object
# education          object
# default           float64
# housing           float64
# loan              float64
# contact            object
# duration            int64
# campaign            int64
# pdays               int64
# previous            int64
# poutcome           object
# emp_var_rate      float64
# cons_price_idx    float64
# cons_conf_idx     float64
# euribor3m         float64
# nr_employed       float64
# y                  object
# month_day_week     object
# dtype: object

# %% [markdown]
# 5. En las columnas de marital y month, poner todos los valores en minúsculas.
#
# 💡 Pista Podréis usar una función o una lambda 💡

# %%
def lower(columna):
    try:
        x = columna.lower()
        return x
    except:
        return np.nan

# %%
df[['marital', 'month_day_week']] = df[['marital', 'month_day_week']].apply(lower)

# %%
df.head(3)
# Out:
#    age        job  marital    education  default  housing  loan    contact  \
# 0   56  housemaid      NaN     basic.4y      0.0      0.0   0.0  telephone
# 1   57   services      NaN  high.school      NaN      0.0   0.0  telephone
# 2   37   services      NaN  high.school      0.0      1.0   0.0  telephone
#
#    duration  campaign  pdays  previous     poutcome  emp_var_rate  \
# 0       261         1    999         0  NONEXISTENT           1.1
# 1       149         1    999         0  NONEXISTENT           1.1
# 2       226         1    999         0  NONEXISTENT           1.1
#
#    cons_price_idx  cons_conf_idx  euribor3m  nr_employed   y  month_day_week
# 0          93.994          -36.4      4.857       5191.0  no             NaN
# 1          93.994          -36.4      4.857       5191.0  no             NaN
# 2          93.994          -36.4      4.857       5191.0  no             NaN

# %% [markdown]
# 6. Para no olvidarnos de la visualización. A través de la visualización, podemos detectar errores, valores atípicos, valores faltantes y otros problemas comunes en los datos que de otra manera podrían ser difíciles de identificar. Para esto vamos a hacer una serie de gráficas que deberán ser incluidas en un subplot. Estas gráficas tienen que ser:
# - Una gráfica donde podamos ver si el tipo de trabajo afecta a que un cliente acepte la oferta.

# %% [markdown]
# - Una gráfica donde podamos ver si el hecho de que un cliente tenga una hipoteca afecta a que acepte la oferta.

# %% [markdown]
# - Una gráfica donde podamos ver si el hecho de que un cliente tenga un prestamo afecta a que acepte la oferta.

# %% [markdown]
# - Una gráfica donde podamos ver si hay una relación entre el numero de días desde el último contacto afecta a que un cliente acepte la oferta

# %% [markdown]
# - Una gráfica donde podamos ver si hay relación entre el resultado de la campaña anterior y si el cliente afecta a que el cliente acepte la oferta.

# %%
df['job'].unique()
# Out:
# array(['housemaid', 'services', 'admin.', 'blue-collar', 'technician',
#        'retired', 'management', 'unemployed', 'self-employed', nan,
#        'entrepreneur', 'student'], dtype=object)

# %%
df['poutcome'].unique()
# Out:
# array(['NONEXISTENT', 'FAILURE', 'SUCCESS'], dtype=object)

# %%
fig, ax = plt.subplots(3,2, figsize=(20,15))

sns.countplot(y='job', data = df, hue = 'campaign', ax = ax[0][0])
sns.countplot(y='housing', data = df, hue = 'campaign', ax = ax[0][1])
sns.countplot(y='loan', data = df, hue = 'campaign', ax = ax[1][0])
sns.scatterplot(y='pdays', data = df, hue = 'campaign', ax = ax[1][1])
sns.countplot(y='poutcome', data = df, hue = 'campaign', ax = ax[2][0])
# Out:
# <AxesSubplot:xlabel='count', ylabel='poutcome'>

# %% [markdown]
# 7. Guardamos el csv para seguir trabajando en el siguiente ejercicio de pair de limpieza.
