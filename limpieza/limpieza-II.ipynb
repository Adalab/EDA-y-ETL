# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.options.display.max_columns = None

# %%
df = pd.read_csv('datos/bank_additional_editado.csv', index_col=0)

# %%
df.head()
# Out:
#    age        job  marital    education  default  housing  loan    contact  \
# 0   56  housemaid  married     basic.4y      0.0      0.0   0.0  telephone
# 1   57   services  married  high.school      NaN      0.0   0.0  telephone
# 2   37   services  married  high.school      0.0      1.0   0.0  telephone
# 3   40     admin.  married     basic.6y      0.0      0.0   0.0  telephone
# 4   56   services  married  high.school      0.0      0.0   1.0  telephone
#
#    duration  campaign  pdays  previous     poutcome  emp_var_rate  \
# 0       261         1    999         0  NONEXISTENT           1.1
# 1       149         1    999         0  NONEXISTENT           1.1
# 2       226         1    999         0  NONEXISTENT           1.1
# 3       151         1    999         0  NONEXISTENT           1.1
# 4       307         1    999         0  NONEXISTENT           1.1
#
#    cons_price_idx  cons_conf_idx  euribor3m  nr_employed   y  month_day_week
# 0          93.994          -36.4      4.857       5191.0  no  ['may', 'mon']
# 1          93.994          -36.4      4.857       5191.0  no  ['may', 'mon']
# 2          93.994          -36.4      4.857       5191.0  no  ['may', 'mon']
# 3          93.994          -36.4      4.857       5191.0  no  ['may', 'mon']
# 4          93.994          -36.4      4.857       5191.0  no  ['may', 'mon']

# %% [markdown]
# ## Pair Programming Limpieza II
#
# ### Hipótesis
#
# 1. La edad, el trabajo, el estado civil, la educación, la situación de deuda y la forma de contacto pueden influir en la probabilidad de que un cliente acepte la oferta.
#
# 2. El número de veces que se ha contactado a un cliente en el pasado (campo campaign), el número de días que han pasado desde el último contacto (campo pdays), y el resultado de la campaña anterior (campo poutcome) pueden afectar la respuesta del cliente a una nueva oferta.
#
# 3. Las variables económicas (tales como el índice de precios al consumidor (cons.price.idx), la tasa de variación del empleo (emp.var.rate), etc.) pueden influir en la probabilidad de que un cliente acepte la oferta.
#
# 4. Los clientes que ya tienen una hipoteca (housing) o un préstamo (loan) pueden ser menos propensos a aceptar una nueva oferta, ya que podrían estar limitados financieramente.

# %% [markdown]
# ### Tareas
#
# 1. Columnas loan, housing y default: estas columnas contienen valores únicos de 0 y 1. Esto puede parecer poco intuitivo a la hora de la extracción de conclusiones y en las visualizaciones. El objetivo de este ejercicio es que cambies los valores númericos por "Si" y "No". A que corresponde cada uno de los valores lo tenéis en el pair de Limpieza I.

# %%
df.sample()
# Out:
#        age          job marital education  default  housing  loan   contact  \
# 28149   45  blue-collar  single  basic.9y      0.0      1.0   0.0  cellular
#
#        duration  campaign  pdays  previous     poutcome  emp_var_rate  \
# 28149       173         1    999         0  NONEXISTENT          -1.8
#
#        cons_price_idx  cons_conf_idx  euribor3m  nr_employed   y  \
# 28149          93.075          -47.1      1.466       5099.1  no
#
#        month_day_week
# 28149  ['apr', 'mon']

# %%
mapa = {1.0: 'si', 0.0: 'no'}

# %%
df['loan'] = df['loan'].map(mapa, na_action= 'ignore')
df['housing'] = df['housing'].map(mapa, na_action= 'ignore')
df['default'] = df['default'].map(mapa, na_action= 'ignore')

# %%
df.sample(10)
# Out:
#        age           job   marital            education default housing loan  \
# 22966   59    management   married    university.degree      no      no   si
# 5527    42  entrepreneur   married             basic.6y      no      no   no
# 24920   34   blue-collar    single          high.school      no      si   no
# 33343   28    unemployed   married          high.school     NaN      no   no
# 23889   41    technician   married  professional.course      no      si   no
# 36904   60       retired  divorced             basic.4y      no      no   no
# 19765   50    unemployed   married  professional.course     NaN      no   no
# 2641    42        admin.    single    university.degree      no      si   no
# 3801    40   blue-collar   married             basic.6y      no      si   no
# 38997   47        admin.   married    university.degree      no      si   si
#
#          contact  duration  campaign  pdays  previous     poutcome  \
# 22966   cellular       168         3    999         0  NONEXISTENT
# 5527   telephone       204         1    999         0  NONEXISTENT
# 24920   cellular       257         1    999         0  NONEXISTENT
# 33343   cellular       216         1    999         1      FAILURE
# 23889   cellular       307         9    999         0  NONEXISTENT
# 36904   cellular       111         5    999         0  NONEXISTENT
# 19765   cellular       135         1    999         0  NONEXISTENT
# 2641   telephone        72         4    999         0  NONEXISTENT
# 3801   telephone       130         3    999         0  NONEXISTENT
# 38997   cellular        67         5    999         0  NONEXISTENT
#
#        emp_var_rate  cons_price_idx  cons_conf_idx  euribor3m  nr_employed  \
# 22966           1.4          93.444          -36.1      4.965       5228.1
# 5527            1.1          93.994          -36.4      4.857       5191.0
# 24920          -0.1          93.200          -42.0      4.153       5195.8
# 33343          -1.8          92.893          -46.2      1.291       5099.1
# 23889           1.4          93.444          -36.1      4.963       5228.1
# 36904          -2.9          92.963          -40.8      1.215       5076.2
# 19765           1.4          93.444          -36.1      4.966       5228.1
# 2641            1.1          93.994          -36.4      4.856       5191.0
# 3801            1.1          93.994          -36.4      4.859       5191.0
# 38997          -3.0          92.713          -33.0      0.717       5023.5
#
#         y  month_day_week
# 22966  no  ['aug', 'mon']
# 5527   no  ['may', 'mon']
# 24920  no  ['nov', 'tue']
# 33343  no  ['may', 'tue']
# 23889  no  ['aug', 'fri']
# 36904  no  ['jun', 'mon']
# 19765  no  ['aug', 'fri']
# 2641   no  ['may', 'tue']
# 3801   no  ['may', 'fri']
# 38997  no  ['dec', 'mon']

# %% [markdown]
# 2. Para la columna de education, si nos fijamos en sus valores únicos veremos que tenemos puntos. El objetivo de este ejercicio es que quitéis los puntos de esos valores y los reemplacéis por espacios.

# %%
df['education'] = df['education'].str.replace('.', ' ')
# Out:
# /tmp/ipykernel_18606/2890631216.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['education'] = df['education'].str.replace('.', ' ')

# %%
df.sample()
# Out:
#       age     job marital    education default housing loan    contact  \
# 3505   44  admin.  single  high school      no      si   no  telephone
#
#       duration  campaign  pdays  previous     poutcome  emp_var_rate  \
# 3505       347         4    999         0  NONEXISTENT           1.1
#
#       cons_price_idx  cons_conf_idx  euribor3m  nr_employed   y  \
# 3505          93.994          -36.4       4.86       5191.0  no
#
#       month_day_week
# 3505  ['may', 'thu']

# %% [markdown]
# 3. Para la columna job, hay un valor único que esta abreviado (admin.), cambiad la abreviatura por el nombre completo.

# %%
df['job'] = df['job'].str.replace('admin.', 'administration')
df.sample(10)
# Out:
# /tmp/ipykernel_18606/4002099604.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['job'] = df['job'].str.replace('admin.', 'administration')
#        age             job   marital          education default housing loan  \
# 2723    45             NaN   married                NaN     NaN     NaN  NaN
# 32051   39     blue-collar   married           basic 4y      no      no   no
# 7034    38   self-employed   married                NaN      no      si   no
# 139     45     blue-collar   married           basic 9y     NaN      si   no
# 2776    49     blue-collar   married           basic 9y      no      si   no
# 4565    29        services   married        high school      no      no   no
# 31886   36     blue-collar   married           basic 9y      no      no   no
# 5497    44      technician   married  university degree      no      no   no
# 26194   31  administration   married  university degree      no      si   no
# 15897   31        services  divorced        high school      no      si   no
#
#          contact  duration  campaign  pdays  previous     poutcome  \
# 2723   telephone       179         1    999         0  NONEXISTENT
# 32051   cellular       155         1    999         0  NONEXISTENT
# 7034   telephone       118         1    999         0  NONEXISTENT
# 139    telephone       461         1    999         0  NONEXISTENT
# 2776   telephone        87         1    999         0  NONEXISTENT
# 4565   telephone       189         2    999         0  NONEXISTENT
# 31886   cellular       115         3    999         0  NONEXISTENT
# 5497   telephone       125         1    999         0  NONEXISTENT
# 26194   cellular       298         2      5         1      SUCCESS
# 15897   cellular       522         1    999         0  NONEXISTENT
#
#        emp_var_rate  cons_price_idx  cons_conf_idx  euribor3m  nr_employed  \
# 2723            1.1          93.994          -36.4      4.859       5191.0
# 32051          -1.8          92.893          -46.2      1.327       5099.1
# 7034            1.1          93.994          -36.4      4.860       5191.0
# 139             1.1          93.994          -36.4      4.857       5191.0
# 2776            1.1          93.994          -36.4      4.859       5191.0
# 4565            1.1          93.994          -36.4      4.856       5191.0
# 31886          -1.8          92.893          -46.2      1.327       5099.1
# 5497            1.1          93.994          -36.4      4.857       5191.0
# 26194          -0.1          93.200          -42.0      4.076       5195.8
# 15897           1.4          93.918          -42.7      4.960       5228.1
#
#          y  month_day_week
# 2723    no  ['may', 'wed']
# 32051   no  ['may', 'thu']
# 7034    no  ['may', 'thu']
# 139    yes  ['may', 'mon']
# 2776    no  ['may', 'wed']
# 4565    no  ['may', 'tue']
# 31886   no  ['may', 'thu']
# 5497    no  ['may', 'mon']
# 26194   no  ['nov', 'thu']
# 15897   no  ['jul', 'mon']

# %% [markdown]
# 4. La columna month_day_week tiene una lista que contiene información muy diferente. El objetivo de este ejercicio es separar esta columna en dos nuevas, donde tengamos los meses en una columna y los días de la semana en otra.

# %%
#df['month_day_week'] = df['month_day_week'].str.replace('[]', 'administration')

# %%
df['month'] = df['month_day_week'].map(lambda x: x[2:5])

# %%
df['day'] = df['month_day_week'].map(lambda x: x[9:12])

# %%
df.sample()
# Out:
#        age         job   marital            education default housing loan  \
# 25150   45  technician  divorced  professional course      no      si   si
#
#         contact  duration  campaign  pdays  previous     poutcome  \
# 25150  cellular       124         1    999         0  NONEXISTENT
#
#        emp_var_rate  cons_price_idx  cons_conf_idx  euribor3m  nr_employed  \
# 25150          -0.1            93.2          -42.0      4.153       5195.8
#
#         y  month_day_week month  day
# 25150  no  ['nov', 'tue']   nov  tue

# %% [markdown]
# 5. Guarda el csv con las columnas limpias para seguir trabajando con este dataframe limpio.

# %%
df.to_csv('datos/bank_additional_editado.csv')
